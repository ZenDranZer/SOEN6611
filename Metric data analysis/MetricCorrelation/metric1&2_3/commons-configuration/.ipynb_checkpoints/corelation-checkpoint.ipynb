# %% [markdown]
# ### Correlation between each coverage metric (Metric 1&2) and test suite effectiveness (Metric 3).
#
# The rationale is that test suites with higher coverage might show better test suite effectiveness.
#
# ### Project: Apache commons-configuration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr
sns.set()

# %% [markdown]
# ### Step 1. Reading, merging data files and data pre-processing

# %%
# read csv of metric 1, 2 and print record count.
df1 = pd.read_csv("commons-config-jacoco.csv")
df1 = df1.sort_values('CLASS')
print(df1.count())
df1.head()
# Out:
# GROUP                  285
# PACKAGE                285
# CLASS                  285
# INSTRUCTION_MISSED     285
# INSTRUCTION_COVERED    285
# BRANCH_MISSED          285
# BRANCH_COVERED         285
# LINE_MISSED            285
# LINE_COVERED           285
# COMPLEXITY_MISSED      285
# COMPLEXITY_COVERED     285
# METHOD_MISSED          285
# METHOD_COVERED         285
# dtype: int64
#                             GROUP                               PACKAGE  \
# 162  Apache Commons Configuration  org.apache.commons.configuration2.io
# 52   Apache Commons Configuration     org.apache.commons.configuration2
# 49   Apache Commons Configuration     org.apache.commons.configuration2
# 33   Apache Commons Configuration     org.apache.commons.configuration2
# 77   Apache Commons Configuration     org.apache.commons.configuration2
#
#                                                  CLASS  INSTRUCTION_MISSED  \
# 162                       AbsoluteNameLocationStrategy                   0
# 52                               AbstractConfiguration                  87
# 49                   AbstractHierarchicalConfiguration                   6
# 33   AbstractHierarchicalConfiguration.DefinedKeysV...                   0
# 77    AbstractHierarchicalConfiguration.DefinedVisitor                   0
#
#      INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 162                   24              0               6            0
# 52                  1403             17             111           11
# 49                   592              1              51            2
# 33                    96              0               6            0
# 77                    21              0               4            0
#
#      LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 162             6                  0                   5              0
# 52            346                 16                 155              1
# 49            138                  1                  61              0
# 33             22                  0                   9              0
# 77              6                  0                   5              0
#
#      METHOD_COVERED
# 162               2
# 52              105
# 49               36
# 33                6
# 77                3

# %%
# read csv of metric 3 and print record count.
df2 = pd.read_csv("commons-config-mutation.csv" )
df2.rename(columns={'Class':'CLASS','Package':'PACKAGE'},inplace=True)
df2['CLASS'] = df2['CLASS'].str.replace('.java', '', case=False)
df2 = df2.sort_values('CLASS')
print(df2.count())
df2.head()
# Out:
# CLASS             177
# PACKAGE           177
# KILLED            177
# NO_COVERAGE       177
# SURVIVED          177
# TIMED_OUT         177
# Total_Mutant      177
# Mutation_Score    177
# dtype: int64
#                                CLASS  \
# 0       AbsoluteNameLocationStrategy
# 1              AbstractConfiguration
# 2  AbstractHierarchicalConfiguration
# 3       AbstractImmutableNodeHandler
# 4       AbstractListDelimiterHandler
#
#                                      PACKAGE  KILLED  NO_COVERAGE  SURVIVED  \
# 0       org.apache.commons.configuration2.io       4            0         0
# 1          org.apache.commons.configuration2     207            3         7
# 2          org.apache.commons.configuration2      87            0         4
# 3     org.apache.commons.configuration2.tree      22            0         0
# 4  org.apache.commons.configuration2.convert      25            1         0
#
#    TIMED_OUT  Total_Mutant  Mutation_Score
# 0          0             4      100.000000
# 1          3           220       94.090909
# 2          0            91       95.604396
# 3          0            22      100.000000
# 4          0            26       96.153846

# %%
def parse_class_values(dataframe):
    dataframe['CLASS'] = dataframe['CLASS'].map(lambda x:  x if (x.find('.') == -1) else  x[:x.find('.')] )
    dataframe = dataframe.groupby(dataframe['CLASS']).aggregate(sum).reset_index()
    return dataframe

# %%
def inner_join_dataframes(dataframe1, dataframe2):
    data =  pd.merge(left=dataframe1,right=dataframe2, left_on='CLASS', right_on='CLASS')
    return data

# %%
# parse class values and group common classes in df1 - metric 1,2
df1 = parse_class_values(df1)
df1 = df1.sort_values('CLASS')

#calculate Statement Coverage
df1['STATEMENT_COVERAGE'] =  (df1['LINE_COVERED'] / (df1['LINE_COVERED'] + df1['LINE_MISSED'])) * 100

#calculate Branch Coverage
df1['BRANCH_COVERAGE'] =  (df1['BRANCH_COVERED'] / (df1['BRANCH_COVERED'] + df1['BRANCH_MISSED'])) * 100

print(df1.count())
df1.head()
# Out:
# CLASS                  187
# INSTRUCTION_MISSED     187
# INSTRUCTION_COVERED    187
# BRANCH_MISSED          187
# BRANCH_COVERED         187
# LINE_MISSED            187
# LINE_COVERED           187
# COMPLEXITY_MISSED      187
# COMPLEXITY_COVERED     187
# METHOD_MISSED          187
# METHOD_COVERED         187
# STATEMENT_COVERAGE     187
# BRANCH_COVERAGE        143
# dtype: int64
#                                CLASS  INSTRUCTION_MISSED  INSTRUCTION_COVERED  \
# 0       AbsoluteNameLocationStrategy                   0                   24
# 1              AbstractConfiguration                  87                 1403
# 2  AbstractHierarchicalConfiguration                   6                  709
# 3       AbstractImmutableNodeHandler                   0                  115
# 4       AbstractListDelimiterHandler                   5                  133
#
#    BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# 0              0               6            0             6
# 1             17             111           11           346
# 2              1              61            2           166
# 3              0              14            0            24
# 4              1              21            1            27
#
#    COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  METHOD_COVERED  \
# 0                  0                   5              0               2
# 1                 16                 155              1             105
# 2                  1                  75              0              45
# 3                  0                  22              0              15
# 4                  1                  17              0               7
#
#    STATEMENT_COVERAGE  BRANCH_COVERAGE
# 0          100.000000       100.000000
# 1           96.918768        86.718750
# 2           98.809524        98.387097
# 3          100.000000       100.000000
# 4           96.428571        95.454545

# %%
data = inner_join_dataframes(df2, df1)
data.count()
# Out:
# CLASS                  177
# PACKAGE                177
# KILLED                 177
# NO_COVERAGE            177
# SURVIVED               177
# TIMED_OUT              177
# Total_Mutant           177
# Mutation_Score         177
# INSTRUCTION_MISSED     177
# INSTRUCTION_COVERED    177
# BRANCH_MISSED          177
# BRANCH_COVERED         177
# LINE_MISSED            177
# LINE_COVERED           177
# COMPLEXITY_MISSED      177
# COMPLEXITY_COVERED     177
# METHOD_MISSED          177
# METHOD_COVERED         177
# STATEMENT_COVERAGE     177
# BRANCH_COVERAGE        143
# dtype: int64

# %%
data.head()
# Out:
#                                CLASS  \
# 0       AbsoluteNameLocationStrategy
# 1              AbstractConfiguration
# 2  AbstractHierarchicalConfiguration
# 3       AbstractImmutableNodeHandler
# 4       AbstractListDelimiterHandler
#
#                                      PACKAGE  KILLED  NO_COVERAGE  SURVIVED  \
# 0       org.apache.commons.configuration2.io       4            0         0
# 1          org.apache.commons.configuration2     207            3         7
# 2          org.apache.commons.configuration2      87            0         4
# 3     org.apache.commons.configuration2.tree      22            0         0
# 4  org.apache.commons.configuration2.convert      25            1         0
#
#    TIMED_OUT  Total_Mutant  Mutation_Score  INSTRUCTION_MISSED  \
# 0          0             4      100.000000                   0
# 1          3           220       94.090909                  87
# 2          0            91       95.604396                   6
# 3          0            22      100.000000                   0
# 4          0            26       96.153846                   5
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                   24              0               6            0
# 1                 1403             17             111           11
# 2                  709              1              61            2
# 3                  115              0              14            0
# 4                  133              1              21            1
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0             6                  0                   5              0
# 1           346                 16                 155              1
# 2           166                  1                  75              0
# 3            24                  0                  22              0
# 4            27                  1                  17              0
#
#    METHOD_COVERED  STATEMENT_COVERAGE  BRANCH_COVERAGE
# 0               2          100.000000       100.000000
# 1             105           96.918768        86.718750
# 2              45           98.809524        98.387097
# 3              15          100.000000       100.000000
# 4               7           96.428571        95.454545

# %% [markdown]
# ### Step 2. Ploting Co-relation Graph
#
# #### 1. Metric 3 and 1
# Mutation Score and Statement coverage

# %%
plt.figure(figsize=(10, 6))
ax = sns.scatterplot(x="Mutation_Score", y="STATEMENT_COVERAGE", data=data)
plt.ylabel("STATEMENT_COVERAGE%")
plt.title("Mutation Score and Statement coverage")
# Out:
# Text(0.5, 1.0, 'Mutation Score and Statement coverage')

# %% [markdown]
# ##### Corelation:

# %%
data[['Mutation_Score','STATEMENT_COVERAGE']].corr(method ='spearman')
# Out:
#                     Mutation_Score  STATEMENT_COVERAGE
# Mutation_Score            1.000000            0.712588
# STATEMENT_COVERAGE        0.712588            1.000000

# %% [markdown]
# The rationale is that test suites with higher Statement coverage show better test suite effectiveness.

# %% [markdown]
# #### 2. Metric 3 and 2
# Mutation Score and Branch Coverage

# %%
plt.figure(figsize=(10, 6))
ax = sns.scatterplot(x="Mutation_Score", y="BRANCH_COVERAGE", data=data)
plt.ylabel("BRANCH_COVERAGE%")
plt.title("Mutation Score and Branch Coverage")
# Out:
# Text(0.5, 1.0, 'Mutation Score and Branch Coverage')

# %% [markdown]
# Corelation:

# %%
data[['Mutation_Score','BRANCH_COVERAGE']].corr(method ='spearman')
# Out:
#                  Mutation_Score  BRANCH_COVERAGE
# Mutation_Score         1.000000         0.609225
# BRANCH_COVERAGE        0.609225         1.000000

# %% [markdown]
# The rationale is that test suites with higher Branch coverage show better test suite effectiveness.
